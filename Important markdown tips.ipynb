# %% [markdown]
# # Markdown in jupyter notebook

# %% [markdown]
# # The tips in markdown are:-
#
# ### 1. Headings
# ### 2. Bold
# ### 3. Italic
# ### 4. Bullets
# ### 5. Numbered lists
# ### 6. Mathematical symbols
# ### 7. Indented quoting
# ### 8. Line breaks
# ### 9. Image
# ### 10. Colours
# ### 11. Links

# %% [markdown]
# # 1.Headings

# %% [markdown]
# # A. TITLE:-

# %%
# To write a title on your jupyter notebook you yo press escape on the Code line press M for markdown then type #

# %% [markdown]
# ## B. Major headings

# %%
#To write a Major heading on your jupyter notebook you yo press escape on the Code line press M for markdown then type ##

# %% [markdown]
# ### C. Sub headings

# %%
# To write a subheading on your jupyter notebook you yo press escape on the Code line press M for markdown then type ###

# %% [markdown]
# #### D. 4th level subheadings

# %%
# To write a 4th level subheading on your jupyter notebook you yo press escape on the Code line press M for markdown then type ####

# %% [markdown]
# # 2. BOLD
#
# A. use code b  tags # note how i wrote it below
#
# <b> This is bold text
#
# B.  '**' which means  "Double asterisk on both sides of the text"
#
# **This is a bold text**
#
# C.'__' which means "Double underscore on both sides of the phrase or clause"
#
# __This is a bold text__

# %% [markdown]
# # 3. Italic
# #### there are two ways to it:-
# A. "Single asterisk" that is '*'
#
# example:- *This is an italic text*
#
# B. "Single Underscore" That is '_'
#
# example:- _This is an italic text_

# %% [markdown]
# # 4. Bullets
# A.Circular bullet:-
# use the dash sign (-) with a space after it or use an asterisk (*) sign with a space after it.
#
#
# B.Sub bullet:-
# To create a sub bullet,use a tab followed by a dash and a space.or yoouse an asterisk instead of a dash
#
# example of the two types of bullets respectively:-
#
# - This is Bullet:
# * This is Bullet:
#
#     - this is a sub bullet
#     * this is a sub bullet

# %% [markdown]
# # 5. Numbered lists
# start with 1. followed by a space.start each line with some numbers and a period then a space. Tab to indent to get sub numbering.
#
# 1. Line number one
# 2. Line number two
#
#     1. subline number one
#     2. subline number two

# %% [markdown]
# # 6. Mathematical symbols
# use the dollar sign for mathematical symbols
#
# for example:-
#  300 $-$ 5 $*$ 20 $+$ 100 $=$ ?

# %% [markdown]
# # 7. Indented quoting
# use a greater than sign and the a space,then type the text.the text will be indented and also have a gray horizontal line until the next carriage return
#
# example:-
#
# > This is the first line of the first Blockquotes<br>
# This is the second line of the first Blockquotes
#
# > This is the first line of the 2nd Blockquotes<br>
# This is the second line of the 2nd Blockquotes

# %% [markdown]
# # 8. Line  breaks:-
# use code : (br) with the the less than and greater than around it like a bracket
# example:-
#
# line break <br> line break

# %% [markdown]
# # 9. Image
# you can attach image files directly to the Markdown cell.Drag and drop your image to the  markdown cell attached to the notebook
# ![Screenshot%20%289%29.png](attachment:Screenshot%20%289%29.png)

# %% [markdown]
# # 10. Colors
# use this code: (font color=blue|red|green|pink|yellow>Text</font)note:-this just to show the different colours yoy can pick but note for the code to run you must start it with a less than and also end the font with a greater than
#
# example
#
# <font color=blue>Font color is blue</font>
#
# <font color=yellow>Font color is yellow</font>
#
# <font color=red>Font color is red</font>

# %% [markdown]
# # 11. Links
# use this code to insert links and test all links: you will write (link text) but in a list format then write the url side by side eg(http://url) and you can also put another description to the original url
#
# Example:-
# [link text](http://url)
#
# [click here to Google](https://www.google.com/)

# %% [markdown]
# # THE END
